# %%
import tensorflow as tf
import pandas as pd
import numpy as np

from keras.models import Sequential
from keras.layers import Dense, Activation
import keras.backend as K


data = pd.read_csv("Blocks/BlockData2.txt")
x_train = data.iloc[:,0:1].values
y_train = data.iloc[:,1:2].values



rand = np.random.random((1000,1))
layers = np.random.randint(2,size=(1000,1))

# %%
model = Sequential()
model.add(Dense(24, activation = 'relu', input_dim=1))
model.add(Dense(1, activation = 'sigmoid'))

# %%
def mean_pred(t, p):
    return K.mean(p)

model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=[ mean_pred])
model.summary()
# Out:
# WARNING:tensorflow:From D:\Anaconda\envs\TestANN\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From D:\Anaconda\envs\TestANN\lib\site-packages\keras\backend\tensorflow_backend.py:3376: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From D:\Anaconda\envs\TestANN\lib\site-packages\tensorflow_core\python\ops\nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 24)                48
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 25
# =================================================================
# Total params: 73
# Trainable params: 73
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train,
          y_train,
          batch_size=24, 
          epochs = 90,
          callbacks= None,
          shuffle= True,
         )
# Out:
# WARNING:tensorflow:From D:\Anaconda\envs\TestANN\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From D:\Anaconda\envs\TestANN\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From D:\Anaconda\envs\TestANN\lib\site-packages\keras\backend\tensorflow_backend.py:2741: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Epoch 1/90
# WARNING:tensorflow:From D:\Anaconda\envs\TestANN\lib\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From D:\Anaconda\envs\TestANN\lib\site-packages\keras\backend\tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From D:\Anaconda\envs\TestANN\lib\site-packages\keras\backend\tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From D:\Anaconda\envs\TestANN\lib\site-packages\keras\backend\tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From D:\Anaconda\envs\TestANN\lib\site-packages\keras\backend\tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 51/51 [==============================] - 1s 10ms/step - loss: 0.6822 - mean_pred: 0.5109
# Epoch 2/90
# 51/51 [==============================] - 0s 136us/step - loss: 0.6704 - mean_pred: 0.5231
# Epoch 3/90
# 51/51 [==============================] - 0s 156us/step - loss: 0.6631 - mean_pred: 0.5310
# Epoch 4/90
# 51/51 [==============================] - 0s 176us/step - loss: 0.6570 - mean_pred: 0.5378
# Epoch 5/90
# 51/51 [==============================] - 0s 117us/step - loss: 0.6515 - mean_pred: 0.5440
# Epoch 6/90
# 51/51 [==============================] - 0s 156us/step - loss: 0.6465 - mean_pred: 0.5499
# Epoch 7/90
# 51/51 [==============================] - 0s 156us/step - loss: 0.6419 - mean_pred: 0.5555
# Epoch 8/90
# 51/51 [==============================] - 0s 156us/step - loss: 0.6375 - mean_pred: 0.5609
# Epoch 9/90
# 51/51 [==============================] - 0s 156us/step - loss: 0.6333 - mean_pred: 0.5662
# Epoch 10/90
# 51/51 [==============================] - 0s 137us/step - loss: 0.6293 - mean_pred: 0.5715
# Epoch 11/90
# 51/51 [==============================] - 0s 156us/step - loss: 0.6254 - mean_pred: 0.5767
# Epoch 12/90
# 51/51 [==============================] - 0s 137us/step - loss: 0.6216 - mean_pred: 0.5818
# Epoch 13/90
# Epoch 66/90
# 51/51 [==============================] - 0s 117us/step - loss: 0.5537 - mean_pred: 0.7564
# Epoch 67/90
# 51/51 [==============================] - 0s 137us/step - loss: 0.5537 - mean_pred: 0.7591
# Epoch 68/90
# 51/51 [==============================] - 0s 137us/step - loss: 0.5537 - mean_pred: 0.7565
# Epoch 69/90
# 51/51 [==============================] - 0s 137us/step - loss: 0.5537 - mean_pred: 0.7575
# Epoch 70/90
# 51/51 [==============================] - 0s 117us/step - loss: 0.5537 - mean_pred: 0.7575
# Epoch 71/90
# 51/51 [==============================] - 0s 137us/step - loss: 0.5537 - mean_pred: 0.7574
# Epoch 72/90
# 51/51 [==============================] - 0s 137us/step - loss: 0.5537 - mean_pred: 0.7577
# Epoch 73/90
# 51/51 [==============================] - 0s 117us/step - loss: 0.5537 - mean_pred: 0.7587
# Epoch 74/90
# 51/51 [==============================] - 0s 117us/step - loss: 0.5537 - mean_pred: 0.7569
# Epoch 75/90
# 51/51 [==============================] - 0s 137us/step - loss: 0.5537 - mean_pred: 0.7567
# Epoch 76/90
# 51/51 [==============================] - 0s 137us/step - loss: 0.5537 - mean_pred: 0.7575
# Epoch 77/90
# 51/51 [==============================] - 0s 137us/step - loss: 0.5537 - mean_pred: 0.7573
# Epoch 78/90
# 51/51 [==============================] - 0s 137us/step - loss: 0.5537 - mean_pred: 0.7572
# Epoch 79/90
# 51/51 [==============================] - 0s 137us/step - loss: 0.5537 - mean_pred: 0.7572
# Epoch 80/90
# 51/51 [==============================] - 0s 137us/step - loss: 0.5537 - mean_pred: 0.7564
# Epoch 81/90
# 51/51 [==============================] - 0s 137us/step - loss: 0.5537 - mean_pred: 0.7595
# Epoch 82/90
# 51/51 [==============================] - 0s 156us/step - loss: 0.5537 - mean_pred: 0.7588
# Epoch 83/90
# 51/51 [==============================] - 0s 117us/step - loss: 0.5537 - mean_pred: 0.7589
# Epoch 84/90
# 51/51 [==============================] - 0s 156us/step - loss: 0.5537 - mean_pred: 0.7593
# Epoch 85/90
# 51/51 [==============================] - 0s 117us/step - loss: 0.5537 - mean_pred: 0.7586
# Epoch 86/90
# 51/51 [==============================] - 0s 132us/step - loss: 0.5537 - mean_pred: 0.7556
# Epoch 87/90
# 51/51 [==============================] - 0s 117us/step - loss: 0.5537 - mean_pred: 0.7592
# Epoch 88/90
# 51/51 [==============================] - 0s 157us/step - loss: 0.5537 - mean_pred: 0.7580
# Epoch 89/90
# 51/51 [==============================] - 0s 137us/step - loss: 0.5537 - mean_pred: 0.7567
# Epoch 90/90
# 51/51 [==============================] - 0s 117us/step - loss: 0.5537 - mean_pred: 0.7593

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.InputLayer(input_shape=(60)),
    tf.keras.layers.Dense(60, activation = 'relu'),
    tf.keras.layers.Dense(1,activation='softmax')
])
model.summary()
